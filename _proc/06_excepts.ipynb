# %% [raw]
# ---
# output-file: excepts.html
# title: Exceptions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(BxViolation)
# Out:
# ---
#
# [source](https://github.com/thatgeeman/pybx/blob/main/pybx/excepts.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### BxViolation
#
#
#
# Violation of Bx properties.

# %%
#|output: asis
#| echo: false
show_doc(NoIntersection)
# Out:
# ---
#
# [source](https://github.com/thatgeeman/pybx/blob/main/pybx/excepts.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### NoIntersection
#
#
#
# No intersection of boxes occur.
