# %% [raw]
# ---
# output-file: excepts.html
# title: Exceptions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(NoGroundTruthBxs)
# Out:
# ---
#
# [source](https://github.com/thatgeeman/pybx/blob/master/pybx/excepts.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### NoGroundTruthBxs
#
#
#
# No Ground Truth boxes found.

# %%
#| echo: false
#| output: asis
show_doc(BxViolation)
# Out:
# ---
#
# [source](https://github.com/thatgeeman/pybx/blob/master/pybx/excepts.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### BxViolation
#
#
#
# Violation of Bx properties.

# %%
#| echo: false
#| output: asis
show_doc(NoIntersection)
# Out:
# ---
#
# [source](https://github.com/thatgeeman/pybx/blob/master/pybx/excepts.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### NoIntersection
#
#
#
# No intersection of boxes occur.
